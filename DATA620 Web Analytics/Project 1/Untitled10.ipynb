# %%
from stackapi import StackAPI
from datetime import datetime, date, timedelta
import calendar
Stack_key = "WAAOZng12*dnyZoaR4IRng(("
SITE = StackAPI('stackoverflow', key = Stack_key)

# %%
total_days = 3
d1 = date(2017,5,18)
d2 = d1 - timedelta(days=total_days)
timestamp1 = calendar.timegm(d1.timetuple())
timestamp2 = calendar.timegm(d2.timetuple())

# %%
#questions = SITE.fetch('questions', fromdate = timestamp2, todate=timestamp1)
#answers = SITE.fetch('answers', fromdate = timestamp2, todate=timestamp1)

# %%
import numpy as np
import pandas as pd

questions = SITE.fetch('questions', fromdate = timestamp2, todate=timestamp1)
#stackAPI_df = pd.DataFrame.from_dict(SITE.fetch('questions', fromdate = timestamp2, todate=timestamp1, page=1))
#stackAPI_df = pd.DataFrame(questions)

#i=1
#while questions['has_more'try] and i < 10:
#    questions = SITE.fetch('questions', fromdate = timestamp2, todate=timestamp1, page=i+1)
#    stackAPI_df.append(questions, ignore_index=True)
#    i+=1
SAdf = pd.DataFrame.from_dict(questions)
i=1
while questions['has_more'] and i < 100:
    questions = SITE.fetch('questions', fromdate = timestamp2, todate=timestamp1, page=i+1)
    tdf = pd.DataFrame.from_dict(questions)
    SAdf = pd.concat([SAdf, tdf])
    i+=1

# %%
import collections
import operator

Qitems = SAdf['items'].apply(pd.Series)

flattened = []
for x in Qitems.tags: flattened.extend(x)
    
counter=collections.Counter(flattened)
sorted_topics = sorted(counter.items(), key=operator.itemgetter(1), reverse=True)
top20_topics = [i[0] for i in sorted_topics[:20]]

# %%
#questions = SITE.fetch('questions', fromdate = timestamp2, todate=timestamp1, tagged = top20_topics)

#SAdf = pd.DataFrame.from_dict(questions)
#i=1
#while questions['has_more'] and i < 100:
#    questions = SITE.fetch('questions', fromdate = timestamp2, todate=timestamp1, page=i+1, tagged = top20_topics)
#    tdf = pd.DataFrame.from_dict(questions)
#    SAdf = pd.concat([SAdf, tdf])
#    i+=1

# %%
SA_df = SAdf['items'].apply(pd.Series)
asker = SA_df['owner'].apply(pd.Series)['user_id']
SA_df['asker'] = pd.Series(asker, index=SA_df.index)

ans_qid = SA_df[~np.isnan(SA_df['accepted_answer_id'])]['accepted_answer_id']
ans_id_list = ans_qid.tolist()
ans_id_list = [int(l) for l in ans_id_list]

# %%
#asker = SA_df['owner'].apply(pd.Series)['user_id']
#SA_df['asker'] = pd.Series(asker, index=ANSdf.index)

# %%
#answers = SITE.fetch('/answers/{ids}', ids = ans_id_list[:100])
Ans_df = pd.DataFrame()

#if (len(ans_id_list)) % 100 == 0:
#    i = (len(ans_id_list))/100
#else: i = ((len(ans_id_list))/100)+1

i = len(ans_id_list)
while i > 0:
    if i < 100: j = 0
    else: j = i - 100
    answers = SITE.fetch('/answers/{ids}', ids = ans_id_list[j:i])
    Temp_df = pd.DataFrame.from_dict(answers)
    Ans_df = pd.concat([Ans_df, Temp_df])
    i-=100
    
ANSdf = Ans_df['items'].apply(pd.Series)

# %%
##ANSdf = Ans_df['items'].apply(pd.Series)
#ans_qid = SA_df[~np.isnan(SA_df['accepted_answer_id'])]['accepted_answer_id']
#ans_id_list = ans_qid.tolist()
#ans_id_list = [int(l) for l in ans_id_list]
#Ans_df['answerer'] = Ans_df['owner']
answerer = ANSdf['owner'].apply(pd.Series)['user_id']
#answerer = answerer[~np.isnan(answerer)]
#answerer = answerer.tolist()
#answerer = [int(l) for l in answerer]
ANSdf['answerer'] = pd.Series(answerer, index=ANSdf.index)

# %%
SNAdf_full = pd.merge(SA_df, ANSdf, how='outer', on='question_id')
SNAdf = SNAdf_full[['creation_date_x','is_answered', 'view_count', 'asker', 'creation_date_y', 'answerer', 'tags']]

# %%
#SNAdf
SNAdf
# Out:
#        creation_date_x  is_answered  view_count      asker  creation_date_y  \
# 0           1494996703         True          44  4450004.0     1.498059e+09
# 1           1494930742         True          29  7145217.0     1.497619e+09
# 2           1495003784        False          51  5423108.0              NaN
# 3           1494918876         True          47  2138149.0     1.498028e+09
# 4           1495055029        False          17  1566806.0              NaN
# 5           1494912085        False          16  6643238.0              NaN
# 6           1495019850        False         187   234466.0              NaN
# 7           1495014715         True         144  1654265.0     1.495027e+09
# 8           1495053559         True          32  7778761.0     1.495096e+09
# 9           1494865687        False          31  7998873.0              NaN
# 10          1494998872         True          62  8023293.0              NaN
# 11          1494952421        False          19  4461137.0              NaN
# 12          1494991253        False          32  7995036.0              NaN
# 13          1494833692        False          57  7635096.0              NaN
# 14          1494846764        False          16  7972004.0              NaN
# 15          1494856493        False          46  7819470.0              NaN
# 16          1494853955         True          33  7910454.0     1.494854e+09
# 17          1494839694        False          76  6179529.0              NaN
# 18          1495020230         True          48  4756106.0     1.495021e+09
# 19          1494958795        False          69  3072366.0              NaN
# 20          1495046544        False          25  3296768.0              NaN
# 21          1495030281        False          43  8025396.0              NaN
# 22          1495055236        False          43   487873.0              NaN
# 23          1494842505        False          37  5652672.0              NaN
# 24          1494999999        False          17  5275511.0              NaN
# 25          1495033398        False          59  3646431.0              NaN
# 26          1494964117        False          14  5128054.0              NaN
# 27          1495008695         True          45  7529022.0     1.495009e+09
# 28          1494925292         True          81  6860801.0     1.496948e+09
# 29          1494848322         True          35  2088686.0     1.496870e+09
# ...                ...          ...         ...        ...              ...
# 32191       1494822506        False           7  2500177.0              NaN
# 32192       1494821193        False          18   306719.0              NaN
# 32193       1494820600        False          18  5260644.0              NaN
# 32194       1494812345        False          37  8008334.0              NaN
# 32195       1494808961        False          27  7332811.0              NaN
# 32196       1494814131         True          50  5893657.0     1.494815e+09
# 32197       1494819491        False          26  5209360.0              NaN
# 32198       1494814451        False          30  6293720.0              NaN
# 32199       1494813136         True          51  7656142.0     1.494814e+09
# 32200       1494817214         True          31  7974766.0              NaN
# 32201       1494818109        False          36  7440700.0              NaN
# 32202       1494816448         True          48  1335189.0     1.494817e+09
# 32203       1494815813         True          35  8012028.0              NaN
# 32204       1494812845        False          32   955183.0              NaN
# 32205       1494811508        False          32  7228588.0              NaN
# 32206       1494813184         True          48  7916611.0              NaN
# 32207       1494814012        False          41   569302.0              NaN
# 32208       1494813714        False          50  6643238.0              NaN
# 32209       1494812694         True          24  6207923.0     1.494813e+09
# 32210       1494808431        False          23  8011373.0              NaN
# 32211       1494811857        False          11   599018.0              NaN
# 32212       1494810023        False          21  6412823.0              NaN
# 32213       1494811412        False          43  8011761.0              NaN
# 32214       1494811267        False          27  8011775.0              NaN
# 32215       1494810050         True          28  2696950.0     1.494810e+09
# 32216       1494809818         True          34  2396545.0     1.494810e+09
# 32217       1494808253         True          34  6041389.0     1.494809e+09
# 32218       1494808868        False          15  4893819.0              NaN
# 32219       1494808057        False          17  2543758.0              NaN
# 32220       1494807985        False          34  7771039.0              NaN
#
#         answerer                                               tags
# 0       677694.0                         [javascript, vue.js, weex]
# 1       200987.0                 [javascript, automation, stubbing]
# 2            NaN  [javascript, angular, webpack, sass, platform-...
# 3       857500.0               [javascript, pdf, pdf-viewer, pdfjs]
# 4            NaN   [javascript, validation, zurb-foundation, abide]
# 5            NaN  [javascript, reactjs, react-native, react-navi...
# 6            NaN  [javascript, google-chrome, google-chrome-devt...
# 7      4494425.0  [javascript, html5, validation, recaptcha, goo...
# 8      2096363.0                [javascript, jquery, range, circle]
# 9            NaN  [javascript, unit-testing, phantomjs, karma-mo...
# 10           NaN                            [javascript, html, css]
# 11           NaN           [javascript, json, node.js, xml, xml2js]
# 12           NaN                                       [javascript]
# 13           NaN                            [javascript, html, css]
# 14           NaN                                 [javascript, html]
# 15           NaN         [javascript, angular, typescript, mahjong]
# 16     1250860.0     [javascript, jquery, html, cookies, setcookie]
# 17           NaN           [javascript, jquery, ajax, fullcalendar]
# 18     1922223.0             [javascript, date, datetime, momentjs]
# 19           NaN                      [javascript, angular, ionic2]
# 20           NaN                         [javascript, d3.js, graph]
# 21           NaN        [javascript, arrays, sorting, object, pair]
# 22           NaN              [javascript, parse.com, parse-server]
# 23           NaN                       [javascript, php, angularjs]
# 24           NaN  [javascript, angularjs, angular-bootstrap, boi...
# 25           NaN                       [javascript, php, angularjs]
# 26           NaN                      [javascript, node.js, buffer]
# 27       19068.0                                       [javascript]
# 28      860603.0  [javascript, react-redux, redux-form, react-re...
# 29     2088686.0                  [javascript, node.js, aws-lambda]
# ...          ...                                                ...
# 32191        NaN                              [javascript, twitter]
# 32192        NaN                 [javascript, events, asynchronous]
# 32193        NaN      [javascript, jquery, content-security-policy]
# 32194        NaN                        [javascript, html, reactjs]
# 32195        NaN                              [javascript, reactjs]
# 32196  1123505.0             [javascript, jquery, html, css, html5]
# 32197        NaN              [javascript, arrays, sorting, object]
# 32198        NaN   [javascript, c#, asp.net, datagrid, boundcolumn]
# 32199   513025.0                                       [javascript]
# 32200        NaN               [javascript, multidimensional-array]
# 32201        NaN               [javascript, node.js, express, post]
# 32202      476.0                      [javascript, php, html, json]
# 32203        NaN                       [javascript, arrays, object]
# 32204        NaN  [javascript, node.js, reactjs, react-router, p...
# 32205        NaN  [javascript, html, html5, browser, webbrowser-...
# 32206        NaN                                 [javascript, html]
# 32207        NaN                                       [javascript]
# 32208        NaN  [javascript, reactjs, react-native, react-navi...
# 32209  2737131.0              [javascript, ionic-framework, ionic2]
# 32210        NaN                               [javascript, jquery]
# 32211        NaN                            [javascript, svg, gulp]
# 32212        NaN      [javascript, html, asp.net-mvc-4, kendo-grid]
# 32213        NaN       [javascript, asp.net, asp.net-mvc, webforms]
# 32214        NaN                                 [javascript, html]
# 32215      476.0                                 [javascript, html]
# 32216  8003769.0  [javascript, arrays, callback, higher-order-fu...
# 32217  4201323.0                          [javascript, jquery, api]
# 32218        NaN           [javascript, android, cordova, phonegap]
# 32219        NaN  [javascript, node.js, database, firebase, fire...
# 32220        NaN   [javascript, php, jquery, html, bootstrap-modal]
#
# [32221 rows x 7 columns]

# %%
flattened = []
for x in SNAdf.tags: flattened.extend(x)

# %%
import collections
import operator
counter=collections.Counter(flattened)
sorted_topics = sorted(counter.items(), key=operator.itemgetter(1), reverse=True)
top20_topics = [i[0] for i in sorted_topics[:20]]

# %%
sorted_topics
# Out:
# [(u'javascript', 5369),
#  (u'java', 4200),
#  (u'python', 3786),
#  (u'c#', 3200),
#  (u'php', 3065),
#  (u'android', 3022),
#  (u'jquery', 2004),
#  (u'html', 1990),
#  (u'ios', 1568),
#  (u'css', 1407),
#  (u'mysql', 1325),
#  (u'c++', 1253),
#  (u'r', 1191),
#  (u'angular', 1186),
#  (u'node.js', 1174),
#  (u'sql', 1165),
#  (u'json', 958),
#  (u'swift', 944),
#  (u'arrays', 868),
#  (u'angularjs', 858),
#  (u'sql-server', 780),
#  (u'asp.net', 690),
#  (u'reactjs', 673),
#  (u'excel', 637),
#  (u'python-3.x', 604),
#  (u'spring', 594),
#  (u'linux', 589),
#  (u'c', 569),
#  (u'laravel', 495),
#  (u'ajax', 491),
#  (u'.net', 488),
#  (u'regex', 485),
#  (u'amazon-web-services', 476),
#  (u'firebase', 472),
#  (u'django', 468),
#  (u'asp.net-mvc', 463),
#  (u'xml', 451),
#  (u'pandas', 450),
#  (u'ruby-on-rails', 443),
#  (u'typescript', 436),
#  (u'wordpress', 433),
#  (u'azure', 433),
#  (u'python-2.7', 428),
#  (u'postgresql', 415),
#  (u'visual-studio', 413),
#  (u'vba', 410),
#  (u'database', 400),
#  (u'windows', 378),
#  (u'mongodb', 370),
#  (u'bash', 367),
#  (u'docker', 367),
#  (u'xcode', 363),
#  (u'spring-boot', 363),
#  (u'twitter-bootstrap', 353),
#  (u'excel-vba', 352),
#  (u'git', 338),
#  (u'rest', 330),
#  (u'ruby', 322),
#  (u'scala', 321),
#  (u'powershell', 316),
#  (u'tensorflow', 313),
#  (u'selenium', 300),
#  (u'multithreading', 300),
#  (u'jenkins', 299),
#  (u'apache', 293),
#  (u'apache-spark', 285),
#  (u'wpf', 279),
#  (u'string', 279),
#  (u'react-native', 277),
#  (u'objective-c', 269),
#  (u'oracle', 268),
#  (u'swift3', 266),
#  (u'maven', 260),
#  (u'dataframe', 259),
#  (u'android-studio', 256),
#  (u'list', 256),
#  (u'csv', 252),
#  (u'symfony', 245),
#  (u'api', 244),
#  (u'osx', 243),
#  (u'css3', 238),
#  (u'asp.net-core', 238),
#  (u'firebase-database', 233),
#  (u'shell', 232),
#  (u'elasticsearch', 230),
#  (u'html5', 226),
#  (u'image', 223),
#  (u'unit-testing', 221),
#  (u'hibernate', 217),
#  (u'webpack', 215),
#  (u'function', 215),
#  (u'matlab', 213),
#  (u'ssl', 211),
#  (u'cordova', 206),
#  (u'vb.net', 202),
#  (u'opencv', 196),
#  (u'express', 196),
#  (u'eclipse', 194),
#  (u'vue.js', 190),
#  (u'matplotlib', 190),
#  (u'http', 187),
#  (u'ionic-framework', 185),
#  (u'winforms', 182),
#  (u'laravel-5', 180),
#  (u'entity-framework', 176),
#  (u'tsql', 175),
#  (u'hadoop', 175),
#  (u'forms', 173),
#  (u'algorithm', 172),
#  (u'tomcat', 172),
#  (u'file', 171),
#  (u'ionic2', 170),
#  (u'sorting', 167),
#  (u'qt', 166),
#  (u'google-chrome', 165),
#  (u'selenium-webdriver', 164),
#  (u'numpy', 164),
#  (u'iphone', 160),
#  (u'npm', 159),
#  (u'codeigniter', 159),
#  (u'xamarin', 157),
#  (u'sockets', 157),
#  (u'unity3d', 155),
#  (u'spring-mvc', 155),
#  (u'authentication', 154),
#  (u'amazon-ec2', 154),
#  (u'linq', 147),
#  (u'asp.net-web-api', 147),
#  (u'go', 146),
#  (u'batch-file', 145),
#  (u'sqlite', 144),
#  (u'email', 143),
#  (u'dictionary', 143),
#  (u'javafx', 142),
#  (u'ms-access', 141),
#  (u'amazon-s3', 140),
#  (u'svg', 140),
#  (u'validation', 139),
#  (u'c++11', 139),
#  (u'visual-studio-2017', 138),
#  (u'date', 138),
#  (u'pdf', 138),
#  (u'performance', 138),
#  (u'uwp', 138),
#  (u'google-maps', 136),
#  (u'for-loop', 136),
#  (u'nginx', 134),
#  (u'visual-studio-2015', 133),
#  (u'datetime', 131),
#  (u'asynchronous', 131),
#  (u'jquery-ui', 130),
#  (u'd3.js', 129),
#  (u'server', 129),
#  (u'.htaccess', 125),
#  (u'jsp', 125),
#  (u'lambda', 123),
#  (u'facebook', 122),
#  (u'github', 122),
#  (u'xaml', 122),
#  (u'assembly', 121),
#  (u'redux', 121),
#  (u'machine-learning', 121),
#  (u'android-fragments', 120),
#  (u'encryption', 120),
#  (u'testing', 119),
#  (u'ggplot2', 119),
#  (u'laravel-5.4', 117),
#  (u'apache-kafka', 116),
#  (u'flask', 115),
#  (u'groovy', 115),
#  (u'ssh', 115),
#  (u'ubuntu', 112),
#  (u'loops', 112),
#  (u'web-services', 111),
#  (u'canvas', 110),
#  (u'firefox', 110),
#  (u'arduino', 108),
#  (u'optimization', 107),
#  (u'wcf', 107),
#  (u'iis', 106),
#  (u'jdbc', 105),
#  (u'shiny', 105),
#  (u'heroku', 105),
#  (u'templates', 103),
#  (u'meteor', 103),
#  (u'vuejs2', 102),
#  (u'web-scraping', 102),
#  (u'three.js', 100),
#  (u'scikit-learn', 100),
#  (u'security', 100),
#  (u'plot', 99),
#  (u'google-app-engine', 98),
#  (u'excel-formula', 98),
#  (u'swing', 98),
#  (u'listview', 97),
#  (u'botframework', 97),
#  (u'deep-learning', 97),
#  (u'class', 96),
#  (u'internet-explorer', 95),
#  (u'jpa', 95),
#  (u'woocommerce', 95),
#  (u'ecmascript-6', 94),
#  (u'neural-network', 93),
#  (u'unix', 92),
#  (u'android-layout', 92),
#  (u'curl', 92),
#  (u'xpath', 90),
#  (u'https', 90),
#  (u'animation', 90),
#  (u'spring-security', 89),
#  (u'object', 88),
#  (u'video', 88),
#  (u'kubernetes', 88),
#  (u'intellij-idea', 86),
#  (u'generics', 86),
#  (u'xamarin.forms', 86),
#  (u'gradle', 85),
#  (u'session', 85),
#  (u'aws-lambda', 85),
#  (u'networking', 85),
#  (u'logging', 85),
#  (u'debugging', 85),
#  (u'user-interface', 85),
#  (u'join', 85),
#  (u'mysqli', 84),
#  (u'opengl', 83),
#  (u'google-analytics', 83),
#  (u'multidimensional-array', 83),
#  (u'sql-server-2008', 83),
#  (u'cassandra', 83),
#  (u'perl', 82),
#  (u'if-statement', 82),
#  (u'merge', 80),
#  (u'svn', 80),
#  (u'awk', 80),
#  (u'highcharts', 80),
#  (u'google-spreadsheet', 80),
#  (u'oauth-2.0', 80),
#  (u'random', 80),
#  (u'charts', 80),
#  (u'automation', 80),
#  (u'delphi', 79),
#  (u'jenkins-pipeline', 79),
#  (u'recyclerview', 78),
#  (u'datatables', 78),
#  (u'google-cloud-platform', 78),
#  (u'variables', 78),
#  (u'oop', 78),
#  (u'serialization', 77),
#  (u'cookies', 77),
#  (u'group-by', 77),
#  (u'functional-programming', 76),
#  (u'haskell', 76),
#  (u'proxy', 75),
#  (u'matrix', 75),
#  (u'.net-core', 75),
#  (u'django-models', 75),
#  (u'model-view-controller', 75),
#  (u'parsing', 75),
#  (u'uitableview', 75),
#  (u'google-chrome-extension', 75),
#  (u'keras', 75),
#  (u'xcode8', 74),
#  (u'module', 74),
#  (u'react-redux', 73),
#  (u'ansible', 73),
#  (u'redirect', 72),
#  (u'caching', 72),
#  (u'mod-rewrite', 72),
#  (u'servlets', 71),
#  (u'neo4j', 71),
#  (u'docker-compose', 71),
#  (u'pyspark', 71),
#  (u'audio', 70),
#  (u'google-apps-script', 70),
#  (u'hive', 70),
#  (u'sharepoint', 70),
#  (u'asp.net-core-mvc', 70),
#  (u'stored-procedures', 70),
#  (u'sql-server-2012', 70),
#  (u'eloquent', 70),
#  (u'jsf', 70),
#  (u'firebase-authentication', 70),
#  (u'dependency-injection', 70),
#  (u'junit', 70),
#  (u'vscode', 70),
#  (u'realm', 69),
#  (u'graph', 69),
#  (u'ruby-on-rails-5', 69),
#  (u'tfs', 68),
#  (u'timer', 68),
#  (u'filter', 68),
#  (u'push-notification', 68),
#  (u'sass', 68),
#  (u'jasmine', 67),
#  (u'cakephp', 67),
#  (u'tcp', 67),
#  (u'checkbox', 66),
#  (u'sed', 66),
#  (u'dom', 66),
#  (u'grails', 66),
#  (u'yii2', 66),
#  (u'xml-parsing', 65),
#  (u'struct', 65),
#  (u'image-processing', 65),
#  (u'url', 65),
#  (u'tkinter', 65),
#  (u'rxjs', 65),
#  (u'java-ee', 65),
#  (u'webview', 65),
#  (u'datatable', 64),
#  (u'wso2', 64),
#  (u'search', 64),
#  (u'cors', 64),
#  (u'redis', 64),
#  (u'select', 63),
#  (u'arraylist', 63),
#  (u'magento', 63),
#  (u'twitter', 62),
#  (u'spring-data-jpa', 61),
#  (u'web', 61),
#  (u'sapui5', 61),
#  (u'paypal', 60),
#  (u'gridview', 60),
#  (u'soap', 60),
#  (u'post', 60),
#  (u'asp.net-mvc-5', 60),
#  (u'ruby-on-rails-4', 60),
#  (u'twitter-bootstrap-3', 60),
#  (u'reporting-services', 60),
#  (u'java-8', 60),
#  (u'angular-cli', 60),
#  (u'mongoose', 60),
#  (u'callback', 60),
#  (u'typo3', 60),
#  (u'xamarin.android', 59),
#  (u'google-bigquery', 59),
#  (u'raspberry-pi', 59),
#  (u'google-api', 59),
#  (u'joomla', 58),
#  (u'kotlin', 58),
#  (u'jmeter', 58),
#  (u'bluetooth', 57),
#  (u'centos', 57),
#  (u'pip', 57),
#  (u'scripting', 56),
#  (u'microsoftgraph', 56),
#  (u'angular-material', 56),
#  (u'websocket', 55),
#  (u'facebook-graph-api', 55),
#  (u'winapi', 55),
#  (u'cmd', 55),
#  (u'iframe', 55),
#  (u'asp.net-mvc-4', 55),
#  (u'flexbox', 55),
#  (u'active-directory', 55),
#  (u'vector', 55),
#  (u'django-rest-framework', 55),
#  (u'c++14', 55),
#  (u'kendo-ui', 55),
#  (u'continuous-integration', 55),
#  (u'google-drive-sdk', 55),
#  (u'pointers', 55),
#  (u'deployment', 55),
#  (u'recursion', 55),
#  (u'gulp', 55),
#  (u'arm', 55),
#  (u'promise', 55),
#  (u'protractor', 54),
#  (u'boost', 54),
#  (u'ibm-bluemix', 54),
#  (u'playframework', 54),
#  (u'scrapy', 53),
#  (u'apache-camel', 53),
#  (u'bitmap', 53),
#  (u'button', 53),
#  (u'doctrine2', 53),
#  (u'netbeans', 53),
#  (u'certificate', 52),
#  (u'path', 52),
#  (u'jwt', 52),
#  (u'rstudio', 51),
#  (u'ffmpeg', 51),
#  (u'razor', 51),
#  (u'html-table', 50),
#  (u'login', 50),
#  (u'terminal', 50),
#  (u'primefaces', 50),
#  (u'grep', 50),
#  (u'youtube', 50),
#  (u'angular2-template', 50),
#  (u'solr', 50),
#  (u'jackson', 50),
#  (u'calendar', 50),
#  (u'gcc', 50),
#  (u'datepicker', 50),
#  (u'testng', 50),
#  (u'aws-api-gateway', 50),
#  (u'inheritance', 50),
#  (u'unicode', 50),
#  (u'xsd', 50),
#  (u'indexing', 50),
#  (u'makefile', 50),
#  (u'appium', 49),
#  (u'android-activity', 49),
#  (u'dll', 49),
#  (u'service', 48),
#  (u'enums', 48),
#  (u'autocomplete', 48),
#  (u'drop-down-menu', 48),
#  (u'xslt', 48),
#  (u'amazon-dynamodb', 48),
#  (u'mobile', 48),
#  (u'java-stream', 48),
#  (u'buffer', 48),
#  (u'build', 48),
#  (u'colors', 48),
#  (u'sonarqube', 47),
#  (u'duplicates', 47),
#  (u'events', 47),
#  (u'outlook', 46),
#  (u'permissions', 46),
#  (u'file-upload', 45),
#  (u'layout', 45),
#  (u'printing', 45),
#  (u'spring-data', 45),
#  (u'libgdx', 45),
#  (u'rust', 45),
#  (u'vim', 45),
#  (u'unity5', 45),
#  (u'spark-dataframe', 45),
#  (u'azure-data-lake', 45),
#  (u'upload', 45),
#  (u'cryptography', 45),
#  (u'sqlalchemy', 45),
#  (u'phpunit', 45),
#  (u'mvvm', 45),
#  (u'import', 45),
#  (u'encoding', 45),
#  (u'statistics', 45),
#  (u'ssms', 45),
#  (u'angular2-services', 45),
#  (u'ckeditor', 45),
#  (u'web-applications', 45),
#  (u'vbscript', 45),
#  (u'azure-cosmosdb', 45),
#  (u'asp.net-web-api2', 45),
#  (u'udp', 45),
#  (u'request', 45),
#  (u'oauth', 45),
#  (u'extjs', 45),
#  (u'macros', 45),
#  (u'mocking', 45),
#  (u'design', 45),
#  (u'scipy', 45),
#  (u'kendo-grid', 45),
#  (u'thymeleaf', 45),
#  (u'firebase-cloud-messaging', 45),
#  (u'convert', 45),
#  (u'apache-spark-sql', 44),
#  (u'vue-component', 44),
#  (u'react-native-android', 44),
#  (u'twilio', 44),
#  (u'utf-8', 44),
#  (u'nullpointerexception', 44),
#  (u'split', 43),
#  (u'jboss', 43),
#  (u'safari', 43),
#  (u'google-maps-api-3', 43),
#  (u'dropdown', 42),
#  (u'url-rewriting', 42),
#  (u'exception', 42),
#  (u'ssis', 42),
#  (u'coldfusion', 42),
#  (u'drag-and-drop', 42),
#  (u'mariadb', 42),
#  (u'beautifulsoup', 42),
#  (u'nlp', 42),
#  (u'memory', 42),
#  (u'time', 41),
#  (u'babeljs', 41),
#  (u'data-binding', 41),
#  (u'dplyr', 41),
#  (u'design-patterns', 41),
#  (u'python-requests', 41),
#  (u'karma-runner', 41),
#  (u'rabbitmq', 40),
#  (u'jenkins-plugins', 40),
#  (u'angular-ui-router', 40),
#  (u'time-series', 40),
#  (u'retrofit2', 40),
#  (u'youtube-api', 40),
#  (u'retrofit', 40),
#  (u'routes', 40),
#  (u'openxml', 40),
#  (u'gitlab', 40),
#  (u'ftp', 40),
#  (u'binding', 40),
#  (u'jupyter-notebook', 40),
#  (u'boto3', 40),
#  (u'count', 40),
#  (u'chef', 40),
#  (u'google-analytics-api', 40),
#  (u'leaflet', 40),
#  (u'async-await', 40),
#  (u'ember.js', 40),
#  (u'pycharm', 40),
#  (u'cocoapods', 40),
#  (u'observable', 40),
#  (u'crystal-reports', 40),
#  (u'wix', 40),
#  (u'nuget', 40),
#  (u'camera', 40),
#  (u'plsql', 40),
#  (u'cocoa', 40),
#  (u'akka', 40),
#  (u'artificial-intelligence', 40),
#  (u'mongodb-query', 40),
#  (u'webgl', 40),
#  (u'prestashop', 40),
#  (u'text', 40),
#  (u'http-headers', 40),
#  (u'react-navigation', 40),
#  (u'pyqt5', 40),
#  (u'datagrid', 40),
#  (u'memory-management', 40),
#  (u'x86', 40),
#  (u'elixir', 40),
#  (u'scroll', 40),
#  (u'electron', 40),
#  (u'command-line', 40),
#  (u'spark-streaming', 40),
#  (u'laravel-5.3', 39),
#  (u'admob', 39),
#  (u'digital-signature', 39),
#  (u'office-js', 38),
#  (u'webpack-2', 38),
#  (u'input', 38),
#  (u'format', 38),
#  (u'office365', 38),
#  (u'ms-word', 38),
#  (u'lua', 38),
#  (u'core-data', 38),
#  (u'reflection', 38),
#  (u'tuples', 38),
#  (u'openssl', 38),
#  (u'locking', 38),
#  (u'itunesconnect', 37),
#  (u'drupal', 37),
#  (u'angular2-routing', 37),
#  (u'uicollectionview', 37),
#  (u'bluetooth-lowenergy', 37),
#  (u'polymer', 36),
#  (u'web-crawler', 36),
#  (u'pyqt', 36),
#  (u'version-control', 36),
#  (u'react-router', 36),
#  (u'amazon', 36),
#  (u'concurrency', 35),
#  (u'data.table', 35),
#  (u'spring-integration', 35),
#  (u'triggers', 35),
#  (u'memory-leaks', 35),
#  (u'mapbox', 35),
#  (u'linux-kernel', 35),
#  (u'sas', 35),
#  (u'socket.io', 35),
#  (u'owin', 35),
#  (u'pivot', 35),
#  (u'qml', 35),
#  (u'phpmailer', 35),
#  (u'methods', 35),
#  (u'android-gradle', 35),
#  (u'jestjs', 35),
#  (u'plotly', 35),
#  (u'oracle11g', 35),
#  (u'jar', 35),
#  (u'jupyter', 35),
#  (u'log4j', 35),
#  (u'client', 35),
#  (u'database-design', 35),
#  (u'unity-container', 35),
#  (u'browser', 35),
#  (u'codeigniter-3', 35),
#  (u'f#', 35),
#  (u'aggregation-framework', 35),
#  (u'stl', 35),
#  (u'vb6', 35),
#  (u'graphql', 35),
#  (u'controller', 35),
#  (u'dynamic', 35),
#  (u'adobe', 35),
#  (u'azure-functions', 35),
#  (u'spring-batch', 35),
#  (u'freemarker', 35),
#  (u'swagger', 35),
#  (u'orm', 35),
#  (u'material-design', 35),
#  (u'plugins', 35),
#  (u'combobox', 35),
#  (u'webforms', 35),
#  (u'openshift', 35),
#  (u'google-visualization', 35),
#  (u'aggregate', 35),
#  (u'notepad++', 35),
#  (u'openerp', 35),
#  (u'cmake', 35),
#  (u'cron', 35),
#  (u'math', 35),
#  (u'macos-sierra', 35),
#  (u'ipad', 35),
#  (u'powerbi', 35),
#  (u'report', 35),
#  (u'apache-poi', 35),
#  (u'c#-4.0', 35),
#  (u'datagridview', 35),
#  (u'amazon-redshift', 35),
#  (u'cuda', 35),
#  (u'phantomjs', 35),
#  (u'angular2-forms', 35),
#  (u'clojure', 35),
#  (u'menu', 34),
#  (u'notifications', 34),
#  (u'error-handling', 34),
#  (u'prolog', 34),
#  (u'logstash', 34),
#  (u'tabs', 34),
#  (u'angularjs-directive', 34),
#  (u'save', 34),
#  (u'linked-list', 34),
#  (u'geolocation', 33),
#  (u'qt5', 33),
#  (u'gson', 33),
#  (u'itext', 33),
#  (u'parallel-processing', 33),
#  (u'bar-chart', 33),
#  (u'components', 33),
#  (u'kafka-consumer-api', 32),
#  (u'nested', 32),
#  (u'windows-10', 32),
#  (u'msbuild', 32),
#  (u'grid', 32),
#  (u'gdb', 31),
#  (u'identityserver4', 31),
#  (u'autolayout', 31),
#  (u'odbc', 31),
#  (u'activemq', 31),
#  (u'build.gradle', 30),
#  (u'replace', 30),
#  (u'dns', 30),
#  (u'prestashop-1.6', 30),
#  (u'data-structures', 30),
#  (u'apache-flink', 30),
#  (u'timezone', 30),
#  (u'anaconda', 30),
#  (u'google-places-api', 30),
#  (u'laravel-5.2', 30),
#  (u'modal-dialog', 30),
#  (u'package', 30),
#  (u'sublimetext3', 30),
#  (u'h2o', 30),
#  (u'enzyme', 30),
#  (u'shopify', 30),
#  (u'cucumber', 30),
#  (u'relational-database', 30),
#  (u'pagination', 30),
#  (u'phonegap', 30),
#  (u'slim', 30),
#  (u'primeng', 30),
#  (u'static', 30),
#  (u'lumen', 30),
#  (u'graphics', 30),
#  (u'marklogic', 30),
#  (u'html5-canvas', 30),
#  (u'shinyapps', 30),
#  (u'bootstrap-modal', 30),
#  (u'refactoring', 30),
#  (u'jinja2', 30),
#  (u'html5-video', 30),
#  (u'ssrs-2012', 30),
#  (u'ionic3', 30),
#  (u'actionscript-3', 30),
#  (u'installation', 30),
#  (u'vs-team-services', 30),
#  (u'struts2', 30),
#  (u'azure-service-fabric', 30),
#  (u'knockout.js', 30),
#  (u'bots', 30),
#  (u'header', 30),
#  (u'drupal-8', 30),
#  (u'cakephp-3.0', 30),
#  (u'conv-neural-network', 30),
#  (u'laravel-eloquent', 30),
#  (u'android-volley', 30),
#  (u'celery', 30),
#  (u'ldap', 30),
#  (u'powershell-v3.0', 30),
#  (u'entity-framework-6', 30),
#  (u'x86-64', 30),
#  (u'azure-web-sites', 30),
#  (u'phpmyadmin', 30),
#  (u'wkwebview', 30),
#  (u'log4j2', 30),
#  (u'routing', 30),
#  (u'u-sql', 30),
#  (u'sql-server-2014', 30),
#  (u'ssas', 30),
#  (u'jsf-2.2', 30),
#  (u'insert', 30),
#  (u'powerpoint', 30),
#  (u'xampp', 30),
#  (u'devexpress', 30),
#  (u'iterator', 30),
#  (u'git-bash', 30),
#  (u'alamofire', 30),
#  (u'apache2', 30),
#  (u'directory', 30),
#  (u'sum', 30),
#  (u'tags', 30),
#  (u'gps', 30),
#  (u'exception-handling', 30),
#  (u'android-xml', 30),
#  (u'hash', 30),
#  (u'google-calendar', 30),
#  (u'windows-azure-storage', 30),
#  (u'phpstorm', 30),
#  (u'deserialization', 30),
#  (u'cxf', 30),
#  (u'constructor', 30),
#  (u'kibana', 29),
#  (u'vaadin', 29),
#  (u'android-databinding', 29),
#  (u'onclick', 29),
#  (u'hazelcast', 29),
#  (u'material-ui', 29),
#  (u'export', 29),
#  (u'classification', 28),
#  (u'pdo', 28),
#  (u'aes', 28),
#  (u'int', 28),
#  (u'elastic-beanstalk', 28),
#  (u'authorization', 28),
#  (u'internet-explorer-11', 28),
#  (u'javafx-8', 28),
#  (u'word-vba', 28),
#  (u'collections', 27),
#  (u'lucene', 27),
#  (u'karma-jasmine', 27),
#  (u'applescript', 27),
#  (u'json.net', 27),
#  (u'wordpress-theming', 27),
#  (u'jquery-select2', 27),
#  (u'talend', 27),
#  (u'ms-office', 27),
#  (u'sails.js', 26),
#  (u'wireshark', 26),
#  (u'repository', 26),
#  (u'api.ai', 26),
#  (u'openid-connect', 26),
#  (u'environment-variables', 26),
#  (u'model', 26),
#  (u'range', 26),
#  (u'blade', 25),
#  (u'android-ndk', 25),
#  (u'aframe', 25),
#  (u'gnu-make', 25),
#  (u'visual-studio-2012', 25),
#  (u'tidyverse', 25),
#  (u'garbage-collection', 25),
#  (u'windows-7', 25),
#  (u'byte', 25),
#  (u'conditional', 25),
#  (u'uiwebview', 25),
#  (u'uiimage', 25),
#  (u'mapping', 25),
#  (u'rmarkdown', 25),
#  (u'liquibase', 25),
#  (u'imagemagick', 25),
#  (u'signal-processing', 25),
#  (u'location', 25),
#  (u'rx-swift', 25),
#  (u'hashmap', 25),
#  (u'resources', 25),
#  (u'azure-table-storage', 25),
#  (u'process', 25),
#  (u'tableau', 25),
#  (u'command-line-interface', 25),
#  (u'osgi', 25),
#  (u'wso2carbon', 25),
#  (u'android-camera', 25),
#  (u'configuration', 25),
#  (u'drawing', 25),
#  (u'apollo', 25),
#  (u'composer-php', 25),
#  (u'glassfish', 25),
#  (u'network-programming', 25),
#  (u'packages', 25),
#  (u'formatting', 25),
#  (u'google-compute-engine', 25),
#  (u'couchdb', 25),
#  (u'hdfs', 25),
#  (u'postgis', 25),
#  (u'initialization', 25),
#  (u'8086', 25),
#  (u'sharepoint-2013', 25),
#  (u'powershell-v2.0', 25),
#  (u'mpi', 25),
#  (u'regression', 25),
#  (u'pygame', 25),
#  (u'fs', 25),
#  (u'cordova-plugins', 25),
#  (u'chart.js', 25),
#  (u'download', 25),
#  (u'configure', 25),
#  (u'key', 25),
#  (u'jersey', 25),
#  (u'requirejs', 25),
#  (u'openstreetmap', 25),
#  (u'polymorphism', 25),
#  (u'computer-vision', 25),
#  (u'time-complexity', 25),
#  (u'mean', 25),
#  (u'visual-studio-2008', 25),
#  (u'pentaho', 25),
#  (u'doctrine', 25),
#  (u'httpclient', 25),
#  (u'sybase', 25),
#  (u'try-catch', 25),
#  (u'foreach', 25),
#  (u'google-cloud-storage', 25),
#  (u'elasticsearch-5', 25),
#  (u'eclipse-plugin', 25),
#  (u'auth0', 25),
#  (u'sdk', 25),
#  (u'append', 25),
#  (u'mqtt', 25),
#  (u'while-loop', 25),
#  (u'serial-port', 25),
#  (u'netsuite', 25),
#  (u'panel', 25),
#  (u'magento2', 25),
#  (u'textbox', 25),
#  (u'activerecord', 25),
#  (u'fluid', 25),
#  (u'mule', 25),
#  (u'android-proguard', 25),
#  (u'httprequest', 25),
#  (u'seaborn', 25),
#  (u'omnet++', 25),
#  (u'firebase-storage', 25),
#  (u'gis', 25),
#  (u'bouncycastle', 25),
#  (u'ibm-mobilefirst', 25),
#  (u'latex', 25),
#  (u'filtering', 25),
#  (u'html-email', 25),
#  (u'openpyxl', 25),
#  (u'odata', 25),
#  (u'sqoop', 25),
#  (u'visual-c++', 25),
#  (u'domain-driven-design', 25),
#  (u'jsf-2', 25),
#  (u'formflow', 25),
#  (u'gpu', 25),
#  (u'character-encoding', 25),
#  (u'outlook-vba', 25),
#  (u'inner-join', 25),
#  (u'base64', 25),
#  (u'robotframework', 25),
#  (u'ubuntu-16.04', 25),
#  (u'angular-material2', 25),
#  (u'pipe', 25),
#  (u'wso2esb', 25),
#  (u'kibana-5', 25),
#  (u'access-vba', 24),
#  (u'azure-active-directory', 24),
#  (u'subset', 24),
#  (u'order', 24),
#  (u'pdfbox', 24),
#  (u'sbt', 24),
#  (u'parse-server', 24),
#  (u'e-commerce', 24),
#  (u'automated-tests', 24),
#  (u'query-builder', 23),
#  (u'parse.com', 23),
#  (u'teradata', 23),
#  (u'jira', 23),
#  (u'microservices', 23),
#  (u'vhdl', 23),
#  (u'theano', 23),
#  (u'cypher', 23),
#  (u'travis-ci', 22),
#  (u'kendo-asp.net-mvc', 22),
#  (u'etl', 22),
#  (u'scrollview', 22),
#  (u'docusignapi', 22),
#  (u'stanford-nlp', 22),
#  (u'wso2-am', 22),
#  (u'io', 22),
#  (u'fullcalendar', 22),
#  (u'laravel-4', 22),
#  (u'numbers', 22),
#  (u'value', 22),
#  (u'annotations', 22),
#  (u'casting', 22),
#  (u'stream', 22),
#  (u'redhat', 22),
#  (u'windows-10-universal', 22),
#  (u'debian', 22),
#  (u'mocha', 21),
#  (u'web-config', 21),
#  (u'uiviewcontroller', 21),
#  (u'http-status-code-404', 21),
#  (u'dependencies', 21),
#  (u'parameters', 21),
#  (u'salesforce', 21),
#  (u'prepared-statement', 21),
#  (u'google-chrome-devtools', 21),
#  (u'linker', 21),
#  (u'jms', 20),
#  (u'sms', 20),
#  (u'mingw', 20),
#  (u'linechart', 20),
#  (u'uml', 20),
#  (u'facebook-messenger-bot', 20),
#  (u'scope', 20),
#  (u'odoo-9', 20),
#  (u'config', 20),
#  (u'microsoft-edge', 20),
#  (u'progress-bar', 20),
#  (u'sap', 20),
#  (u'android-cardview', 20),
#  (u'twig', 20),
#  (u'binary', 20),
#  (u'virtual-machine', 20),
#  (u'undefined', 20),
#  (u'sumo', 20),
#  (u'intel', 20),
#  (u'nativescript', 20),
#  (u'acl', 20),
#  (u'hex', 20),
#  (u'mask', 20),
#  (u'amazon-iam', 20),
#  (u'axis', 20),
#  (u'nunit', 20),
#  (u'amazon-emr', 20),
#  (u'content-management-system', 20),
#  (u'kali-linux', 20),
#  (u'synchronization', 20),
#  (u'tree', 20),
#  (u'contour', 20),
#  (u'markdown', 20),
#  (u'stack', 20),
#  (u'signalr', 20),
#  (u'flowtype', 20),
#  (u'wget', 20),
#  (u'jax-rs', 20),
#  (u'amqp', 20),
#  (u'nuget-package', 20),
#  (u'single-page-application', 20),
#  (u'rdf', 20),
#  (u'google-sheets-api', 20),
#  (u'directx', 20),
#  (u'system.reactive', 20),
#  (u'abstract-class', 20),
#  (u'pyside', 20),
#  (u'db2', 20),
#  (u'runtime-error', 20),
#  (u'frameworks', 20),
#  (u'python-3.6', 20),
#  (u'python-3.5', 20),
#  (u'azure-documentdb', 20),
#  (u'sparql', 20),
#  (u'ios-autolayout', 20),
#  (u'uiview', 20),
#  (u'ssl-certificate', 20),
#  (u'emr', 20),
#  (u'akka-stream', 20),
#  (u'package.json', 20),
#  (u'flash', 20),
#  (u'jvm', 20),
#  (u'http-post', 20),
#  (u'ibm', 20),
#  (u'create-react-app', 20),
#  (u'vlookup', 20),
#  (u'mono', 20),
#  (u'lodash', 20),
#  (u'capybara', 20),
#  (u'bigdata', 20),
#  (u'mockito', 20),
#  (u'comparison', 20),
#  (u'embedded', 20),
#  (u'google-spreadsheet-api', 20),
#  (u'mapreduce', 20),
#  (u'android-permissions', 20),
#  (u'react-router-v4', 20),
#  (u'excel-2010', 20),
#  (u'single-sign-on', 20),
#  (u'pug', 20),
#  (u'zeromq', 20),
#  ...]

# %%
SNAdf['top20'] = []
SNAdf.loc[~SNAdf['column_name'].isin(some_values)]
for x in top20_topics:
    if x in
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-406-e8cf134d8f4c> in <module>()
# ----> 1 SNAdf['top20'] = []
#       2 SNAdf.loc[~SNAdf['column_name'].isin(some_values)]
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __setitem__(self, key, value)
#    2427         else:
#    2428             # set column
# -> 2429             self._set_item(key, value)
#    2430
#    2431     def _setitem_slice(self, key, value):
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _set_item(self, key, value)
#    2493
#    2494         self._ensure_valid_index(value)
# -> 2495         value = self._sanitize_column(key, value)
#    2496         NDFrame._set_item(self, key, value)
#    2497
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _sanitize_column(self, key, value, broadcast)
#    2664
#    2665             # turn me into an ndarray
# -> 2666             value = _sanitize_index(value, self.index, copy=False)
#    2667             if not isinstance(value, (np.ndarray, Index)):
#    2668                 if isinstance(value, list) and len(value) > 0:
#
# /anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in _sanitize_index(data, index, copy)
#    2877
#    2878     if len(data) != len(index):
# -> 2879         raise ValueError('Length of values does not match length of ' 'index')
#    2880
#    2881     if isinstance(data, PeriodIndex):
#
# ValueError: Length of values does not match length of index

# %%
#SNAdf['top20'] = []
#SNAdf.loc[~SNAdf['column_name'].isin(some_values)]
#for x in top20_topics:
#    if x in 

y for y
